# %% [markdown]
# # Exercise 6.2 Exploring relationships

# %% [markdown]
# ### This script contains the following:
#
# #### 1. Importing Visualization Libraries and Data
#
# #### 2. Exploring Relationships
#
#         Correlations
#         Scatterplots
#         Pair Plots
#         Categorical Plots
# #### 3.Visualizations for exploring relationships

# %% [markdown]
# ### 1. Importing  Libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
#check matplotlib version
matplotlib.__version__
# Out:
# '3.7.0'

# %%
# This option ensures charts creatde are displayed in the notebook without the need to "call" them specifically.
# %matplotlib inline

# %%
# Importing Data set
path=r'C:\Users\swati\Employee Termination Analysis'
df=pd.read_csv(os.path.join(path,'02 Data','Prepared Data','df_merged.csv'), index_col = False)

# %%
df.head()
# Out:
#    Unnamed: 0  employee_id terminationdate_key  age  length_of_service  \
# 0           0         1318            1/1/1900   52                 17
# 1           1         1318            1/1/1900   53                 18
# 2           2         1318            1/1/1900   54                 19
# 3           3         1318            1/1/1900   55                 20
# 4           4         1318            1/1/1900   56                 21
#
#    city_name department_name job_title  store_number gender  ...  \
# 0  Vancouver       Executive       CEO            35   Male  ...
# 1  Vancouver       Executive       CEO            35   Male  ...
# 2  Vancouver       Executive       CEO            35   Male  ...
# 3  Vancouver       Executive       CEO            35   Male  ...
# 4  Vancouver       Executive       CEO            35   Male  ...
#
#   year_of_record employment_status  business_unit job_category population  \
# ...

# %%
# Checking column names
df.columns
# Out:
# Index(['Unnamed: 0', 'employee_id', 'terminationdate_key', 'age',
#        'length_of_service', 'city_name', 'department_name', 'job_title',
#        'store_number', 'gender', 'termreason_desc', 'termtype_desc',
#        'year_of_record', 'employment_status', 'business_unit', 'job_category',
#        'population', '_merge', 'population_flag', 'age_flag',
#        'employ_status_flag', 'Hierarchy'],
#       dtype='object')

# %%
# Dropping column which are not required for further analysis
df = df.drop(['Unnamed: 0'], axis = 1)

# %%
df.head()
# Out:
#    employee_id terminationdate_key  age  length_of_service  city_name  \
# 0         1318            1/1/1900   52                 17  Vancouver
# 1         1318            1/1/1900   53                 18  Vancouver
# 2         1318            1/1/1900   54                 19  Vancouver
# 3         1318            1/1/1900   55                 20  Vancouver
# 4         1318            1/1/1900   56                 21  Vancouver
#
#   department_name job_title  store_number gender termreason_desc  ...  \
# 0       Executive       CEO            35   Male  Not Applicable  ...
# 1       Executive       CEO            35   Male  Not Applicable  ...
# 2       Executive       CEO            35   Male  Not Applicable  ...
# 3       Executive       CEO            35   Male  Not Applicable  ...
# 4       Executive       CEO            35   Male  Not Applicable  ...
#
#   year_of_record  employment_status business_unit job_category population  \
# ...

# %% [markdown]
# ### 2. Exploring Relationships

# %%
# Create a correlation matrix using pandas
df.corr(numeric_only=True)
# Out:
#                     employee_id       age  length_of_service  store_number  \
# employee_id            1.000000 -0.926837          -0.898696     -0.008171
# age                   -0.926837  1.000000           0.910200     -0.005328
# length_of_service     -0.898696  0.910200           1.000000      0.009419
# store_number          -0.008171 -0.005328           0.009419      1.000000
# year_of_record         0.197760 -0.037941           0.238308      0.008165
# population            -0.021637  0.014991           0.017446      0.610011
# employ_status_flag     0.039476 -0.133354          -0.025387      0.019084
# Hierarchy             -0.309576  0.229662           0.266127      0.001007
#
#                     year_of_record  population  employ_status_flag  Hierarchy
# employee_id               0.197760   -0.021637            0.039476  -0.309576
# age                      -0.037941    0.014991           -0.133354   0.229662
# ...

# %% [markdown]
# ### Correlations

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(df.corr(numeric_only=True), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap

# %% [markdown]
# The correlation between employee_id and age, length of service is a given .
#
# There is  a moderate correlation  between store number and population.

# %% [markdown]
# ### Scatterplots

# %%
# length_of_service is more closely correlated with age rather than job category
# Create a scatterplot for the "age" and "length_of_service" columns in seaborn
sns.lmplot(x = 'age', y = 'length_of_service', data = df)

# %% [markdown]
# The largest service peak of around 13 years overlaps with the age peak of above 60 years and with ages between 40-50.They are people who changed careers to join the company.

# %% [markdown]
# ### Pair Plots

# %%
# Keep only the variables you want to use in the pair plot

sub=df[[ 'age','year_of_record','length_of_service','population' ]]

# %%
# Create a pair plot 

g= sns.pairplot(sub)

# %% [markdown]
# ### Categorial Plot

# %%
# Create a histogram
sns.histplot(sub['length_of_service'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='length_of_service', ylabel='Count'>

# %%
# Create a histogram
sns.histplot(sub['age'], bins = 20, kde = True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# Create a categorical plot in seaborn 

sns.set(style="ticks")
g = sns.catplot(x="age", y="job_category", data=df)

# %% [markdown]
# ### 3.Visualizations for exploring relationships

# %%
#bar chart to show gender comparison
df['gender'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#bar chart to show employment status comparison
df['employment_status'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#bar chart to show population according to city 
df['population_flag'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#bar chart to show job category comparison
df['job_category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(5, 5))
sns.countplot(x="age_flag", hue="employment_status", data=df)
# Out:
# <Axes: xlabel='age_flag', ylabel='count'>

# %% [markdown]
# #### Terminations are more after the 60 years of age(Old-age)

# %%
plt.figure(figsize=(5, 5))
sns.countplot(x="population_flag", hue="employment_status", data=df)
# Out:
# <Axes: xlabel='population_flag', ylabel='count'>

# %% [markdown]
# #### Maximum number of employees are from the mega city in which the ratio of active to terminated status of the employee is higher.
# #### Number of employees from the town are less compared to mega city but much higher compared to rural area.
# #### The least number of employees are from rural areas and the ratio of active to terminated status of the employee is lower.

# %%
#bar chart to show city name comparison
df['city_name'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# #### In the above bar chart, we see that Vancouver and Victoria have the highest share of terminated employees. This skewness might be because the higest concentration of employees in the dataset is in these 2 cities.

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x="job_category", hue="employment_status", data=df)
# Out:
# <Axes: xlabel='job_category', ylabel='count'>

# %% [markdown]
# Maximum number of "Employees" are the ones with the employee job title and the number of ones with active status is more than the number of ones with terminated status.

# %%
plt.figure(figsize=(5, 5))
sns.countplot(x="year_of_record", hue="employment_status", data=df)
# Out:
# <Axes: xlabel='year_of_record', ylabel='count'>

# %% [markdown]
# 2014 had an unusually high number of employment terminations.

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x="business_unit", hue="employment_status", data=df)
# Out:
# <Axes: xlabel='business_unit', ylabel='count'>

# %% [markdown]
# ####  More number of employees are from the stores and not from the head-office and cases of termination are also higher in stores  than cases of termination in the head-office .
